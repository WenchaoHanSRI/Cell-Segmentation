# %% [markdown]
# <a href="https://colab.research.google.com/github/WenchaoHanSRI/Cell-Segmentation/blob/main/Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wandb
from PIL import Image
from matplotlib import pyplot as plt
import os
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.13.4-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 30.5 MB/s
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.28-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 66.2 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (6.0)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 10.5 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.9-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 53.2 MB/s
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 51.9 MB/s
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 85.5 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 49.8 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 55.8 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 20.4 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 64.9 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 72.9 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 72.2 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 77.6 MB/s
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=33a94e37e86348e1fba655988c5a3dad724007514f1f4c95f4741439d5d78f46
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.28 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.9 smmap-5.0.0 wandb-0.13.4

# %% [markdown]
# # Get the github repository files

# %%
# !git clone https://github.com/WenchaoHanSRI/U_net
# Out:
# Cloning into 'U_net'...
# remote: Enumerating objects: 265, done.
# remote: Counting objects: 100% (190/190), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 265 (delta 110), reused 138 (delta 79), pack-reused 75
# Receiving objects: 100% (265/265), 16.29 MiB | 7.39 MiB/s, done.
# Resolving deltas: 100% (132/132), done.

# %% [markdown]
# # Switch the running file directory

# %%
# %cd /content/U_net/U_net_WH/
# Out:
# /content/U_net/U_net_WH

# %% [markdown]
# # Get the pre-trained model

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=18jRivGhFium-URAhMMHTV-js-MsBUMzR' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=18jRivGhFium-URAhMMHTV-js-MsBUMzR" -O checkpoint_epoch15.pth && rm -rf /tmp/cookies.txt
# Out:
# --2022-10-09 19:11:48--  https://docs.google.com/uc?export=download&confirm=t&id=18jRivGhFium-URAhMMHTV-js-MsBUMzR
# Resolving docs.google.com (docs.google.com)... 74.125.24.101, 74.125.24.139, 74.125.24.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.24.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-98-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/figrbqq9efqud648dfj9l6e59623krtr/1665342675000/04603435069551975460/*/18jRivGhFium-URAhMMHTV-js-MsBUMzR?e=download&uuid=ec0ac8fa-f033-4edc-a4fa-677a609e5a95 [following]
# Warning: wildcards not supported in HTTP.
# --2022-10-09 19:11:49--  https://doc-0k-98-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/figrbqq9efqud648dfj9l6e59623krtr/1665342675000/04603435069551975460/*/18jRivGhFium-URAhMMHTV-js-MsBUMzR?e=download&uuid=ec0ac8fa-f033-4edc-a4fa-677a609e5a95
# Resolving doc-0k-98-docs.googleusercontent.com (doc-0k-98-docs.googleusercontent.com)... 172.217.194.132, 2404:6800:4003:c04::84
# Connecting to doc-0k-98-docs.googleusercontent.com (doc-0k-98-docs.googleusercontent.com)|172.217.194.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 124242773 (118M) [application/x-zip]
# Saving to: ‘checkpoint_epoch15.pth’
#
# checkpoint_epoch15. 100%[===================>] 118.49M  58.8MB/s    in 2.0s
#
# 2022-10-09 19:11:52 (58.8 MB/s) - ‘checkpoint_epoch15.pth’ saved [124242773/124242773]

# %% [markdown]
# # Run the script for validation
# In this example case, validation only applied to the two sample images saved in 'data/testimgsall' directory. The predicted mask is validated against the groundtruth mask in 'data/testmasksall' directory.
#
# **User can review the results in the provided links after running the script below:**

# %%
# !python3 validate.py
# Out:
# INFO: Using device cuda
# INFO: Network:
# 	3 input channels
# 	2 output channels (classes)
# 	Transposed conv upscaling
# INFO: Creating dataset with 2 examples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.13.4
# wandb: Run data is saved locally in /content/U_net/U_net_WH/wandb/run-20221009_191208-3pcz3bo2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fancy-dew-1
# wandb: ⭐️ View project at https://wandb.ai/anony-moose-415515/U-Net?apiKey=9f6bbae110e99bdc16feb3fa704e9a572242ca99
# wandb: 🚀 View run at https://wandb.ai/anony-moose-415515/U-Net/runs/3pcz3bo2?apiKey=9f6bbae110e99bdc16feb3fa704e9a572242ca99
# wandb: WARNING Do NOT share these links with anyone. They can be used to claim your runs.
# INFO: Starting training:
#         Batch size:      1
#         Validation size: 2
#         Checkpoints:     True
#         Device:          cuda
#         Images scaling:  1
#         Mixed Precision: False
#
# ### successfully load the pretrained model ###
# Validation round:   0% 0/2 [00:00<?, ?batch/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/U_net/U_net_WH/evaluate_output.py:22: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   mask_true = mask_true // 255
# Validation round:  50% 1/2 [00:24<00:24, 24.81s/batch]/content/U_net/U_net_WH/evaluate_output.py:22: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   mask_true = mask_true // 255
# wandb: WARNING Artifacts logged anonymously cannot be claimed and expire after 7 days.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:      Dice ▁█
# wandb:  accuracy ▁█
# wandb:        f1 ▁█
# wandb: precision █▁
# wandb:    recall ▁█
# wandb:
# wandb: Run summary:
# wandb:      Dice 0.87876
# wandb:  accuracy 0.975
# wandb:        f1 0.87876
# wandb: precision 0.84325
# wandb:    recall 0.91739
# wandb:
# wandb: Synced fancy-dew-1: https://wandb.ai/anony-moose-415515/U-Net/runs/3pcz3bo2?apiKey=9f6bbae110e99bdc16feb3fa704e9a572242ca99
# wandb: Synced 5 W&B file(s), 7 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20221009_191208-3pcz3bo2/logs

# %% [markdown]
# Alternatively, user can run the code below, without using Weights & Biases. The averaged error metrics are printed out and the predicted masks can be find in the /prediction/ folder, which is automatically created.

# %%
# !python3 validate_folder.py
# Out:
# INFO: Using device cuda
# INFO: Network:
# 	3 input channels
# 	2 output channels (classes)
# 	Transposed conv upscaling
# INFO: Creating dataset with 2 examples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# INFO: Settings:
#         Batch size:      1
#         Validation size: 2
#         Checkpoints:     True
#         Device:          cuda
#         Images scaling:  1
#         Mixed Precision: False
#
# ### successfully load the pretrained model ###
# Validation round:   0% 0/2 [00:00<?, ?batch/s]/content/U_net/U_net_WH/evaluate_folder.py:23: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   mask_true = mask_true // 255
# Validation round:  50% 1/2 [00:10<00:10, 10.70s/batch]/content/U_net/U_net_WH/evaluate_folder.py:23: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   mask_true = mask_true // 255
# INFO: Mean error metrics:
#         Dice:      0.8660787343978882
#         f1:        0.8660786833493048
#         precision: 0.8536318553640077
#         recall:    0.880215374971693
#         accuracy:  0.9738527536392212

# %% [markdown]
# # Visualize the prediction results

# %%
## get the image directories
path_cwd = os.getcwd()
path_img = os.path.join(path_cwd, 'data/testimgsall')
path_true_mask = os.path.join(path_cwd, 'data/testmasksall')
path_pred_mask = os.path.join(path_cwd, 'prediction/')

## plot the figures for visualization
fig = plt.figure(figsize=(14, 7))
i = 1
for (f_im, f_tm, f_pm) in zip (os.listdir(path_img), 
                      os.listdir(path_true_mask), 
                      os.listdir(path_pred_mask)):
  ax = fig.add_subplot(2, 3, i)
  img = Image.open(os.path.join
                   (path_img, f_im)
                   )
  ax.imshow(img)
  ax.set_title('Img')
  i += 1
  ax = fig.add_subplot(2, 3, i)
  true_mask = Image.open(os.path.join
                         (path_true_mask, f_tm)
                         )
  ax.imshow(true_mask)
  ax.set_title('True mask')
  i += 1
  ax = fig.add_subplot(2, 3, i)
  pred_mask = Image.open(os.path.join
                         (path_pred_mask, f_pm)
                         )
  ax.imshow(pred_mask)
  ax.set_title('Prediction mask')
  i += 1
plt.show()
